# %%
ROOT_DIR = 'C:\\Users\\arul\\Downloads\\Compressed\\cow_disease'

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    # If GPU is available, set the device to GPU
    device = torch.device("cuda")
    print("GPU is available!")
else:
    # If GPU is not available, set the device to CPU
    device = torch.device("cpu")
    print("GPU is not available, using CPU instead.")
# Out:
# GPU is available!

# %%
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# PyTorch version: 2.3.0+cu121
# CUDA available: True
# CUDA version: 12.1
# GPU device name: NVIDIA GeForce RTX 3060 Ti

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "E:\Arul\internship\Propeller Technologies\Arul\cow_disease\data.yaml"), epochs=25)
# Out:
# Ultralytics YOLOv8.2.22  Python-3.11.4 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# e:\Arul\internship\Propeller Technologies\Arul\cow_disease

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
ls "E:\Arul\internship\Propeller Technologies\Arul\cow_disease\\runs\detect\\train"
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 765F-8422
#
#  Directory of E:\Arul\internship\Propeller Technologies\Arul\cow_disease\runs\detect\train2
#
# 30-07-2024  15:50    <DIR>          .
# 30-07-2024  15:48    <DIR>          ..
# 30-07-2024  15:47             1,692 args.yaml
# 30-07-2024  15:50            95,819 confusion_matrix.png
# 30-07-2024  15:50            98,980 confusion_matrix_normalized.png
# 30-07-2024  15:50           202,378 events.out.tfevents.1722334669.DESKTOP-BSNDQFL.4616.0
# 30-07-2024  15:50           107,777 F1_curve.png
# 30-07-2024  15:48           170,673 labels.jpg
# 30-07-2024  15:48           174,665 labels_correlogram.jpg
# 30-07-2024  15:50            95,141 P_curve.png
# 30-07-2024  15:50            88,512 PR_curve.png
# 30-07-2024  15:50           102,252 R_curve.png
# 30-07-2024  15:50             8,762 results.csv
# 30-07-2024  15:50           274,333 results.png
# 30-07-2024  15:48           519,274 train_batch0.jpg
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_labels.jpg', width=600)
# Out:
# e:\Arul\internship\Propeller Technologies\Arul\cow_disease

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model="E:\Arul\internship\Propeller Technologies\Arul\cow_disease\\runs\detect\\train\weights\\best.pt" conf=0.25 source="E:\Arul\internship\Propeller Technologies\Arul\cow_disease\Lumpy_skin_disease2.jpg" save=True
# Out:
# e:\Arul\internship\Propeller Technologies\Arul\cow_disease
# Ultralytics YOLOv8.2.22 🚀 Python-3.11.4 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 E:\Arul\internship\Propeller Technologies\Arul\cow_disease\Lumpy_skin_disease2.jpg: 416x640 1 lumpy skin diesease, 87.6ms
# Speed: 3.0ms preprocess, 87.6ms inference, 928.2ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='E:\Arul\internship\Propeller Technologies\Arul\cow_disease\\runs\detect\predict2\Lumpy-Skin-Disease.jpg', height=600)
